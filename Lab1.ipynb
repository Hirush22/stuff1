# %% [markdown]
# <a href="https://colab.research.google.com/github/Hirush22/stuff1/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Лабораторная работа №1
#
# В4_Мечани Ира_м1О-415Бки

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

red_dataset = pd.read_csv('/content/sample_data/winequality-white.csv', sep=';')    
white_dataset = pd.read_csv('/content/sample_data/winequality-red.csv', sep=';')   
red_dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
white_dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# Зависимость качества вина от его параметров. Двумерная гистограмма.

# %%
# %matplotlib inline
plt.style.use('default')
fig, axs = plt.subplots(2, 6, figsize=(20,10))

for i in range(11):
    x = i % 2
    y = i // 2
    column = white_dataset.columns[i]
    max_p = max(white_dataset[column])
    min_p = min(white_dataset[column])
    axs[x, y].hist2d(white_dataset['quality'], white_dataset[column], 
        bins = [6, 20], range = [[3, 8],[min_p, max_p]], density = True)
    axs[x, y].set_title(column)
fig.tight_layout()
plt.show()

# %%
# %matplotlib inline
plt.style.use('grayscale')
fig, axs = plt.subplots(2, 6, figsize=(20,10))

for i in range(11):
    x = i % 2
    y = i // 2
    column = red_dataset.columns[i]
    max_p = max(red_dataset[column])
    min_p = min(red_dataset[column])
    axs[x, y].hist2d(red_dataset['quality'], red_dataset[column], 
        bins = [6, 20], range = [[3, 8],[min_p, max_p]], density = True)
    axs[x, y].set_title(column)
fig.tight_layout()
plt.show()

# %% [markdown]
# Выводы:
#  1. Более высокому качеству вина соответствует более низкая плотность
#  2. Высокая концентрация сульфатов в среднем соответствует более высокому качеству вина
#  3. Летучая кислотность ниже у высококачественных вин
#  4. Концентрация лимонной кислоты выше у высококачественных вин
#  5. Концентрация алкоголя выше у качественных вин

# %%
white_corr_matrix = white_dataset.corr()
white_corr_matrix['quality'].sort_values(ascending=False)
# Out:
# quality                 1.000000
# alcohol                 0.476166
# sulphates               0.251397
# citric acid             0.226373
# fixed acidity           0.124052
# residual sugar          0.013732
# free sulfur dioxide    -0.050656
# pH                     -0.057731
# chlorides              -0.128907
# density                -0.174919
# total sulfur dioxide   -0.185100
# volatile acidity       -0.390558
# Name: quality, dtype: float64

# %% [markdown]
# Матрица корреляции (наиболее и наименее значимые результаты параметров)

# %%
red_corr_matrix = red_dataset.corr()
red_corr_matrix['quality'].sort_values(ascending=False)
# Out:
# quality                 1.000000
# alcohol                 0.435575
# pH                      0.099427
# sulphates               0.053678
# free sulfur dioxide     0.008158
# citric acid            -0.009209
# residual sugar         -0.097577
# fixed acidity          -0.113663
# total sulfur dioxide   -0.174737
# volatile acidity       -0.194723
# chlorides              -0.209934
# density                -0.307123
# Name: quality, dtype: float64

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(white_dataset,figsize=(20,30),color='blue')
plt.show()

# %%
scatter_matrix(white_dataset,figsize=(20,10),color='blue')
plt.show()

# %% [markdown]
# Выводы:
#  1. У распределения данных видны относительно четкие зависимости
#  2. Можно построить относительно точную модель
